# %%
import pandas as pd
simulacoes = []
row = {"T":  24.0,
       "Max Estoque":  60,
       "Min Estoque":  1,
       "Qtd inicial estoque":  5,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": -1238.9570244728166,
       "% lucro total": "-118.86%",
       "Lucro/unid tempo": -51.62320935303402,
       "Sim. nsamples":  30,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": -52.89175350774083,
       "Sim. N cenários": 4244,
       "Sim. Intev inicial média":-53.03315720110065,
       "Sim. Intev final média":-52.75034981438101,
       "Sim. Lucro max/unid tempo": 21.373329366857906,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  24.0,
       "Max Estoque":  45,
       "Min Estoque":  1,
       "Qtd inicial estoque":  2,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": -129.31940445213831,
       "% lucro total": "-8.54%",
       "Lucro/unid tempo": -5.3883085188390965,
       "Sim. nsamples":  30,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": -29.694627613270114,
       "Sim. N cenários": 6592,
       "Sim. Intev inicial média":-29.83603109866501,
       "Sim. Intev final média":-29.553224127875218,
       "Sim. Lucro max/unid tempo": 20.159772987540137,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  24.0,
       "Max Estoque":  30,
       "Min Estoque":  1,
       "Qtd inicial estoque":  2,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": 123.3987453980236,
       "% lucro total": "10.58%",
       "Lucro/unid tempo": 5.141614391584317,
       "Sim. nsamples":  30,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 2.5751732809975234,
       "Sim. N cenários": 6475,
       "Sim. Intev inicial média":2.4337651321076383,
       "Sim. Intev final média":2.7165814298874085,
       "Sim. Lucro max/unid tempo": 19.84627176861101,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  24.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  2,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": 311.1940659163277,
       "% lucro total": "29.12%",
       "Lucro/unid tempo": 12.96641941318032,
       "Sim. nsamples":  30,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 13.429833892097507,
       "Sim. N cenários": 1514,
       "Sim. Intev inicial média":13.288455729881571,
       "Sim. Intev final média":13.571212054313444,
       "Sim. Lucro max/unid tempo":20.098316422202096,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  24.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 7,
       "Lucro Total": 525.849643449666,
       "% lucro total": "46.64%",
       "Lucro/unid tempo": 21.91040181040275,
       "Sim. nsamples":  30,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 19.472233202120243,
       "Sim. N cenários": 1088,
       "Sim. Intev inicial média":19.330840695406838,
       "Sim. Intev final média":19.61362570883365,
       "Sim. Lucro max/unid tempo":24.805248501737893,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  24.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 7,
       "Lucro Total": 365.9433146341648,
       "% lucro total": "34.01%",
       "Lucro/unid tempo": 15.247638109756865,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.1,
       "Sim. Alpha": 0.05,
       "Sim. Lucro medio/unid tempo": 19.5195815826433,
       "Sim. N cenários": 6198,
       "Sim. Intev inicial média":19.448870909799485,
       "Sim. Intev final média":19.590292255487118,
       "Sim. Lucro max/unid tempo":24.838021483921306,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  17.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 7,
       "Lucro Total": 437.88676422058563,
       "% lucro total": "59.66%",
       "Lucro/unid tempo": 25.758044954152098,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.3,
       "Sim. Alpha": 0.2,
       "Sim. Lucro medio/unid tempo": 28.281482204631306,
       "Sim. N cenários": 1308,
       "Sim. Intev inicial média":28.069360200026512,
       "Sim. Intev final média":28.4936042092361,
       "Sim. Lucro max/unid tempo":32.595629079019844,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  17.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  40,
       "Custo por unidade": 7,
       "Lucro Total": 329.1287810156076,
       "% lucro total": "53.48%",
       "Lucro/unid tempo": 19.36051653032986,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.3,
       "Sim. Alpha": 0.2,
       "Sim. Lucro medio/unid tempo": 19.16513451797962,
       "Sim. N cenários": 1308,
       "Sim. Intev inicial média":18.953041580317375,
       "Sim. Intev final média":19.377227455641865,
       "Sim. Lucro max/unid tempo":22.40788326534138,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  120.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": 2518.5978881895207,
       "% lucro total": "42.2%",
       "Lucro/unid tempo": 20.98831573491267,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.3,
       "Sim. Alpha": 0.2,
       "Sim. Lucro medio/unid tempo": 18.867353592112575,
       "Sim. N cenários": 100,
       "Sim. Intev inicial média":18.66550710903761,
       "Sim. Intev final média":19.069200075187542,
       "Sim. Lucro max/unid tempo":23.30794231383704,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  120.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": 2221.0857293473605,
       "% lucro total": "39.67%",
       "Lucro/unid tempo": 18.509047744561336,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.1,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 18.90732627058458,
       "Sim. N cenários": 1626,
       "Sim. Intev inicial média":18.83662429118465,
       "Sim. Intev final média":18.97802824998451,
       "Sim. Lucro max/unid tempo":23.362480690472566,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  240.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 10,
       "Lucro Total": 4794.864837821023,
       "% lucro total": "41.49%",
       "Lucro/unid tempo": 19.97860349092093,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.2,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 19.01452042816049,
       "Sim. N cenários": 207,
       "Sim. Intev inicial média":18.87323496435483,
       "Sim. Intev final média":19.155805891966153,
       "Sim. Lucro max/unid tempo":23.495720357971017,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

row = {"T":  240.0,
       "Max Estoque":  20,
       "Min Estoque":  1,
       "Qtd inicial estoque":  3,
       "Preço da unid":  50,
       "Custo por unidade": 7,
       "Lucro Total": 5716.612825451582,
       "% lucro total": "48.39%",
       "Lucro/unid tempo": 23.819220106048256,
       "Sim. nsamples":  100,
       "Sim. Tol": 0.1,
       "Sim. Alpha": 0.1,
       "Sim. Lucro medio/unid tempo": 22.086643926957336,
       "Sim. N cenários": 808,
       "Sim. Intev inicial média":22.015960885594748,
       "Sim. Intev final média":22.157326968319925,
       "Sim. Lucro max/unid tempo":26.767705624186164,
       "Sim. Melhor estoque": "(5,15)"
      }
simulacoes.append(row)

simDF = pd.DataFrame(simulacoes)
simDF
# Out:
#         T  Max Estoque  Min Estoque  Qtd inicial estoque  Preço da unid  \
# 0    24.0           60            1                    5             50
# 1    24.0           45            1                    2             50
# 2    24.0           30            1                    2             50
# 3    24.0           20            1                    2             50
# 4    24.0           20            1                    3             50
# 5    24.0           20            1                    3             50
# 6    17.0           20            1                    3             50
# 7    17.0           20            1                    3             40
# 8   120.0           20            1                    3             50
# 9   120.0           20            1                    3             50
# 10  240.0           20            1                    3             50
# 11  240.0           20            1                    3             50
#
# ...

# %%
simDF.to_csv(r'dadosSim.csv')
